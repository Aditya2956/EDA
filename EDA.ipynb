# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
df = pd.read_csv('Data/coaster_db.csv')
#!dir

# %%
df.shape
# Out:
# (1087, 56)

# %%
pd.options.display.max_columns = 200

# %%
df.head(5)
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# 0  LaMarcus Adna Thompson                NaN  Lift Packed  50 ft (15 m)
# 1            Lina Beecher                NaN          NaN           NaN
# 2                     NaN                NaN          NaN           NaN
# 3          Edwin Prescott                NaN          NaN           NaN
# 4          Edwin Prescott                NaN          NaN           NaN
#
#    Inversions Lift/launch system Cost  \
# 0         NaN            gravity  NaN
# 1         1.0                NaN  NaN
# 2         NaN                NaN  NaN
# 3         1.0                NaN  NaN
# 4         1.0                NaN  NaN
#
#                                               Trains  \
# 0                                                NaN
# 1  a single car. Riders are arranged 1 across in ...
# 2                                                NaN
# 3  a single car. Riders are arranged 2 across in ...
# 4                                                NaN
#
#                 Park section Duration              Capacity G-force  \
# 0  Coney Island Cyclone Site     1:00  1600 riders per hour     2.9
# 1                        NaN      NaN                   NaN      12
# 2                        NaN      NaN                   NaN     NaN
# 3                        NaN      NaN                   NaN     NaN
# 4                        NaN      NaN                   NaN     NaN
#
#                  Designer Max vertical angle          Drop Soft opening date  \
# 0  LaMarcus Adna Thompson                30°  43 ft (13 m)               NaN
# 1            Lina Beecher                NaN           NaN               NaN
# 2                     NaN                NaN           NaN               NaN
# 3         Edward A. Green                NaN           NaN               NaN
# 4         Edward A. Green                NaN           NaN               NaN
#
#   Fast Lane available            Replaced            Track layout  \
# 0                 NaN                 NaN  Gravity pulled coaster
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN  Switchback Railway                     NaN
# 4                 NaN                 NaN                     NaN
#
#   Fastrack available Soft opening date.1 Closing date Opened  Replaced by  \
# 0                NaN                 NaN          NaN    NaN          NaN
# 1                NaN                 NaN         1902    NaN          NaN
# 2                NaN                 NaN          NaN   1895          NaN
# 3                NaN                 NaN         1910    NaN  Giant Racer
# 4                NaN                 NaN         1912    NaN          NaN
#
#   Website Flash Pass Available Must transfer from wheelchair Theme  \
# 0     NaN                  NaN                           NaN   NaN
# 1     NaN                  NaN                           NaN   NaN
# 2     NaN                  NaN                           NaN   NaN
# 3     NaN                  NaN                           NaN   NaN
# 4     NaN                  NaN                           NaN   NaN
#
#   Single rider line available Restraint Style Flash Pass available  \
# 0                         NaN             NaN                  NaN
# 1                         NaN             NaN                  NaN
# 2                         NaN             NaN                  NaN
# 3                         NaN             NaN                  NaN
# 4                         NaN             NaN                  NaN
#
#   Acceleration Restraints Name  year_introduced  latitude  longitude  \
# 0          NaN        NaN  NaN             1884   40.5740   -73.9780
# 1          NaN        NaN  NaN             1895   40.5780   -73.9790
# 2          NaN        NaN  NaN             1896   41.5800   -81.5700
# 3          NaN        NaN  NaN             1901   40.5745   -73.9780
# 4          NaN        NaN  NaN             1901   39.3538   -74.4342
#
#   Type_Main opening_date_clean  speed1    speed2  speed1_value speed1_unit  \
# 0      Wood         1884-06-16  6 mph   9.7 km/h           6.0         mph
# 1      Wood         1895-01-01     NaN       NaN           NaN         NaN
# 2     Other                NaN     NaN       NaN           NaN         NaN
# 3     Steel         1901-01-01     NaN       NaN           NaN         NaN
# 4     Steel         1901-01-01     NaN       NaN           NaN         NaN
#
#    speed_mph  height_value height_unit  height_ft  Inversions_clean  \
# 0        6.0          50.0          ft        NaN                 0
# 1        NaN           NaN         NaN        NaN                 1
# 2        NaN           NaN         NaN        NaN                 0
# 3        NaN           NaN         NaN        NaN                 1
# 4        NaN           NaN         NaN        NaN                 1
#
#    Gforce_clean
# 0           2.9
# 1          12.0
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# Fast Lane available               object
# Replaced                          object
# Track layout                      object
# Fastrack available                object
# Soft opening date.1               object
# Closing date                      object
# Opened                            object
# Replaced by                       object
# Website                           object
# Flash Pass Available              object
# Must transfer from wheelchair     object
# Theme                             object
# Single rider line available       object
# Restraint Style                   object
# Flash Pass available              object
# Acceleration                      object
# Restraints                        object
# Name                              object
# year_introduced                    int64
# latitude                         float64
# longitude                        float64
# Type_Main                         object
# opening_date_clean                object
# speed1                            object
# speed2                            object
# speed1_value                     float64
# speed1_unit                       object
# speed_mph                        float64
# height_value                     float64
# height_unit                       object
# height_ft                        float64
# Inversions_clean                   int64
# Gforce_clean                     float64
# dtype: object

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# min      5.000000      4.000000   13.100000          0.000000      0.800000
# 25%     37.300000     44.000000   51.800000          0.000000      3.400000
# 50%     49.700000     79.000000   91.200000          0.000000      4.000000
# 75%     58.000000    113.000000  131.200000          2.000000      4.500000
# max    149.100000   3937.000000  377.300000         14.000000     12.000000

# %%
df[['coaster_name',
    #'Length', 'Speed', 'Location', 'Status', 'Opening date',
    #   'Type',
    'Manufacturer',
    #'Height restriction', 'Model', 'Height',
    #   'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
    #   'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
    #   'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
    #   'Track layout', 'Fastrack available', 'Soft opening date.1',
    #   'Closing date', 'Opened', 'Replaced by', 'Website',
    #   'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
    #   'Single rider line available', 'Restraint Style',
    #   'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 'latitude', 'longitude', 'Type_Main',
       'opening_date_clean', 
    #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 'height_value', 'height_unit', 'height_ft',
     #  'Inversions_clean', 'Gforce_clean'
      ]]
# Out:
#                                 coaster_name                 Manufacturer  \
# 0                         Switchback Railway       LaMarcus Adna Thompson
# 1                          Flip Flap Railway                 Lina Beecher
# 2     Switchback Railway (Euclid Beach Park)                          NaN
# 3               Loop the Loop (Coney Island)               Edwin Prescott
# 4               Loop the Loop (Young's Pier)               Edwin Prescott
# ...                                      ...                          ...
# 1082                 American Dreier Looping            Anton Schwarzkopf
# 1083               Pantheon (roller coaster)                      Intamin
# 1084               Tron Lightcycle Power Run                       Vekoma
# 1085                                 Tumbili    S&S – Sansei Technologies
# 1086          Wonder Woman Flight of Courage  Rocky Mountain Construction
#
#       year_introduced  latitude  longitude Type_Main opening_date_clean  \
# 0                1884   40.5740   -73.9780      Wood         1884-06-16
# 1                1895   40.5780   -73.9790      Wood         1895-01-01
# 2                1896   41.5800   -81.5700     Other                NaN
# 3                1901   40.5745   -73.9780     Steel         1901-01-01
# 4                1901   39.3538   -74.4342     Steel         1901-01-01
# ...               ...       ...        ...       ...                ...
# 1082             2022       NaN        NaN     Steel                NaN
# 1083             2022   37.2339   -76.6426     Steel         2022-01-01
# 1084             2022       NaN        NaN     Steel         2016-06-16
# 1085             2022       NaN        NaN     Steel                NaN
# 1086             2022       NaN        NaN     Steel         2022-01-01
#
#       speed_mph  height_value height_unit  height_ft
# 0           6.0          50.0          ft        NaN
# 1           NaN           NaN         NaN        NaN
# 2           NaN           NaN         NaN        NaN
# 3           NaN           NaN         NaN        NaN
# 4           NaN           NaN         NaN        NaN
# ...         ...           ...         ...        ...
# 1082       53.0         111.0          ft        NaN
# 1083       73.0         178.0          ft        NaN
# 1084       59.3          78.1          ft        NaN
# 1085       34.0         112.0          ft        NaN
# 1086       58.0         131.0          ft        NaN
#
# [1087 rows x 11 columns]

# %%
df1 = df[['coaster_name',
    #'Length', 'Speed', 'Location', 'Status', 'Opening date',
    #   'Type',
    'Manufacturer',
    #'Height restriction', 'Model', 'Height',
    #   'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
    #   'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
    #   'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
    #   'Track layout', 'Fastrack available', 'Soft opening date.1',
    #   'Closing date', 'Opened', 'Replaced by', 'Website',
    #   'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
    #   'Single rider line available', 'Restraint Style',
    #   'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 'latitude', 'longitude', 'Type_Main',
       'opening_date_clean', 
    #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 'height_value', 'height_unit', 'height_ft',
     #  'Inversions_clean', 'Gforce_clean'
      ]].copy()

# %%
df1
# Out:
#                                 coaster_name                 Manufacturer  \
# 0                         Switchback Railway       LaMarcus Adna Thompson
# 1                          Flip Flap Railway                 Lina Beecher
# 2     Switchback Railway (Euclid Beach Park)                          NaN
# 3               Loop the Loop (Coney Island)               Edwin Prescott
# 4               Loop the Loop (Young's Pier)               Edwin Prescott
# ...                                      ...                          ...
# 1082                 American Dreier Looping            Anton Schwarzkopf
# 1083               Pantheon (roller coaster)                      Intamin
# 1084               Tron Lightcycle Power Run                       Vekoma
# 1085                                 Tumbili    S&S – Sansei Technologies
# 1086          Wonder Woman Flight of Courage  Rocky Mountain Construction
#
#       year_introduced  latitude  longitude Type_Main opening_date_clean  \
# 0                1884   40.5740   -73.9780      Wood         1884-06-16
# 1                1895   40.5780   -73.9790      Wood         1895-01-01
# 2                1896   41.5800   -81.5700     Other                NaN
# 3                1901   40.5745   -73.9780     Steel         1901-01-01
# 4                1901   39.3538   -74.4342     Steel         1901-01-01
# ...               ...       ...        ...       ...                ...
# 1082             2022       NaN        NaN     Steel                NaN
# 1083             2022   37.2339   -76.6426     Steel         2022-01-01
# 1084             2022       NaN        NaN     Steel         2016-06-16
# 1085             2022       NaN        NaN     Steel                NaN
# 1086             2022       NaN        NaN     Steel         2022-01-01
#
#       speed_mph  height_value height_unit  height_ft
# 0           6.0          50.0          ft        NaN
# 1           NaN           NaN         NaN        NaN
# 2           NaN           NaN         NaN        NaN
# 3           NaN           NaN         NaN        NaN
# 4           NaN           NaN         NaN        NaN
# ...         ...           ...         ...        ...
# 1082       53.0         111.0          ft        NaN
# 1083       73.0         178.0          ft        NaN
# 1084       59.3          78.1          ft        NaN
# 1085       34.0         112.0          ft        NaN
# 1086       58.0         131.0          ft        NaN
#
# [1087 rows x 11 columns]

# %%
df1.isna()
# Out:
#       coaster_name  Manufacturer  year_introduced  latitude  longitude  \
# 0            False         False            False     False      False
# 1            False         False            False     False      False
# 2            False          True            False     False      False
# 3            False         False            False     False      False
# 4            False         False            False     False      False
# ...            ...           ...              ...       ...        ...
# 1082         False         False            False      True       True
# 1083         False         False            False     False      False
# 1084         False         False            False      True       True
# 1085         False         False            False      True       True
# 1086         False         False            False      True       True
#
#       Type_Main  opening_date_clean  speed_mph  height_value  height_unit  \
# 0         False               False      False         False        False
# 1         False               False       True          True         True
# 2         False                True       True          True         True
# 3         False               False       True          True         True
# 4         False               False       True          True         True
# ...         ...                 ...        ...           ...          ...
# 1082      False                True      False         False        False
# 1083      False               False      False         False        False
# 1084      False               False      False         False        False
# 1085      False                True      False         False        False
# 1086      False               False      False         False        False
#
#       height_ft
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
# ...         ...
# 1082       True
# 1083       True
# 1084       True
# 1085       True
# 1086       True
#
# [1087 rows x 11 columns]

# %%
df1.isna().sum()
# Out:
# coaster_name            0
# Manufacturer           59
# year_introduced         0
# latitude              275
# longitude             275
# Type_Main               0
# opening_date_clean    250
# speed_mph             150
# height_value          122
# height_unit           122
# height_ft             916
# dtype: int64

# %%
df1.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082    False
# 1083    False
# 1084    False
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
df1.duplicated(subset = ['coaster_name'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082     True
# 1083    False
# 1084     True
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
df1.loc[df1.duplicated(subset = ['coaster_name'])]
# Out:
#                             coaster_name  \
# 43                 Crystal Beach Cyclone
# 60                           Derby Racer
# 61           Blue Streak (Conneaut Lake)
# 167        Big Thunder Mountain Railroad
# 237    Thunder Run (Canada's Wonderland)
# ...                                  ...
# 1063                  Lil' Devil Coaster
# 1064  Little Dipper (Conneaut Lake Park)
# 1080                          Iron Gwazi
# 1082             American Dreier Looping
# 1084           Tron Lightcycle Power Run
#
#                                            Manufacturer  year_introduced  \
# 43                                   Traver Engineering             1927
# 60                                       Fred W. Pearce             1937
# 61                                                  NaN             1938
# 167   Arrow Development (California and Florida)Dyna...             1980
# 237                                          Mack Rides             1986
# ...                                                 ...              ...
# 1063                                           Zamperla             2021
# 1064                            Allan Herschell Company             2021
# 1080                        Rocky Mountain Construction             2022
# 1082                                  Anton Schwarzkopf             2022
# 1084                                             Vekoma             2022
#
#       latitude  longitude Type_Main opening_date_clean  speed_mph  \
# 43     42.8617   -79.0598      Wood         1926-01-01       60.0
# 60     42.4200   -70.9860      Wood         1911-01-01        NaN
# 61     41.6349   -80.3180      Wood         1938-05-23       50.0
# 167        NaN        NaN     Steel                NaN       35.0
# 237    43.8427   -79.5423     Steel         1981-05-23       39.8
# ...        ...        ...       ...                ...        ...
# 1063   40.1343   -74.4434     Steel         1999-01-01        NaN
# 1064   41.6343   -80.3165     Steel         1950-01-01        NaN
# 1080   28.0339   -82.4231     Steel                NaN       76.0
# 1082       NaN        NaN     Steel                NaN       53.0
# 1084       NaN        NaN     Steel         2016-06-16       59.3
#
#       height_value height_unit  height_ft
# 43            96.0          ft        NaN
# 60             NaN         NaN        NaN
# 61            77.0          ft        NaN
# 167          104.0          ft        NaN
# 237           10.0           m       32.8
# ...            ...         ...        ...
# 1063          13.0          ft        NaN
# 1064           NaN         NaN        NaN
# 1080         206.0          ft        NaN
# 1082         111.0          ft        NaN
# 1084          78.1          ft        NaN
#
# [97 rows x 11 columns]

# %%
df1.query('coaster_name == "Crystal Beach Cyclone"')
# Out:
#              coaster_name        Manufacturer  year_introduced  latitude  \
# 39  Crystal Beach Cyclone  Traver Engineering             1926   42.8617
# 43  Crystal Beach Cyclone  Traver Engineering             1927   42.8617
#
#     longitude Type_Main opening_date_clean  speed_mph  height_value  \
# 39   -79.0598      Wood         1926-01-01       60.0          96.0
# 43   -79.0598      Wood         1926-01-01       60.0          96.0
#
#    height_unit  height_ft
# 39          ft        NaN
# 43          ft        NaN

# %%
df1.query('coaster_name == "Little Dipper (Conneaut Lake Park)"')
# Out:
#                             coaster_name             Manufacturer  \
# 69    Little Dipper (Conneaut Lake Park)  Allan Herschell Company
# 1064  Little Dipper (Conneaut Lake Park)  Allan Herschell Company
#
#       year_introduced  latitude  longitude Type_Main opening_date_clean  \
# 69               1950   41.6343   -80.3165     Steel         1950-01-01
# 1064             2021   41.6343   -80.3165     Steel         1950-01-01
#
#       speed_mph  height_value height_unit  height_ft
# 69          NaN           NaN         NaN        NaN
# 1064        NaN           NaN         NaN        NaN

# %%
df.duplicated(subset = ['coaster_name','Location', 'Opening date'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082     True
# 1083    False
# 1084     True
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
df.head(5)
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# 0  LaMarcus Adna Thompson                NaN  Lift Packed  50 ft (15 m)
# 1            Lina Beecher                NaN          NaN           NaN
# 2                     NaN                NaN          NaN           NaN
# 3          Edwin Prescott                NaN          NaN           NaN
# 4          Edwin Prescott                NaN          NaN           NaN
#
#    Inversions Lift/launch system Cost  \
# 0         NaN            gravity  NaN
# 1         1.0                NaN  NaN
# 2         NaN                NaN  NaN
# 3         1.0                NaN  NaN
# 4         1.0                NaN  NaN
#
#                                               Trains  \
# 0                                                NaN
# 1  a single car. Riders are arranged 1 across in ...
# 2                                                NaN
# 3  a single car. Riders are arranged 2 across in ...
# 4                                                NaN
#
#                 Park section Duration              Capacity G-force  \
# 0  Coney Island Cyclone Site     1:00  1600 riders per hour     2.9
# 1                        NaN      NaN                   NaN      12
# 2                        NaN      NaN                   NaN     NaN
# 3                        NaN      NaN                   NaN     NaN
# 4                        NaN      NaN                   NaN     NaN
#
#                  Designer Max vertical angle          Drop Soft opening date  \
# 0  LaMarcus Adna Thompson                30°  43 ft (13 m)               NaN
# 1            Lina Beecher                NaN           NaN               NaN
# 2                     NaN                NaN           NaN               NaN
# 3         Edward A. Green                NaN           NaN               NaN
# 4         Edward A. Green                NaN           NaN               NaN
#
#   Fast Lane available            Replaced            Track layout  \
# 0                 NaN                 NaN  Gravity pulled coaster
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN  Switchback Railway                     NaN
# 4                 NaN                 NaN                     NaN
#
#   Fastrack available Soft opening date.1 Closing date Opened  Replaced by  \
# 0                NaN                 NaN          NaN    NaN          NaN
# 1                NaN                 NaN         1902    NaN          NaN
# 2                NaN                 NaN          NaN   1895          NaN
# 3                NaN                 NaN         1910    NaN  Giant Racer
# 4                NaN                 NaN         1912    NaN          NaN
#
#   Website Flash Pass Available Must transfer from wheelchair Theme  \
# 0     NaN                  NaN                           NaN   NaN
# 1     NaN                  NaN                           NaN   NaN
# 2     NaN                  NaN                           NaN   NaN
# 3     NaN                  NaN                           NaN   NaN
# 4     NaN                  NaN                           NaN   NaN
#
#   Single rider line available Restraint Style Flash Pass available  \
# 0                         NaN             NaN                  NaN
# 1                         NaN             NaN                  NaN
# 2                         NaN             NaN                  NaN
# 3                         NaN             NaN                  NaN
# 4                         NaN             NaN                  NaN
#
#   Acceleration Restraints Name  year_introduced  latitude  longitude  \
# 0          NaN        NaN  NaN             1884   40.5740   -73.9780
# 1          NaN        NaN  NaN             1895   40.5780   -73.9790
# 2          NaN        NaN  NaN             1896   41.5800   -81.5700
# 3          NaN        NaN  NaN             1901   40.5745   -73.9780
# 4          NaN        NaN  NaN             1901   39.3538   -74.4342
#
#   Type_Main opening_date_clean  speed1    speed2  speed1_value speed1_unit  \
# 0      Wood         1884-06-16  6 mph   9.7 km/h           6.0         mph
# 1      Wood         1895-01-01     NaN       NaN           NaN         NaN
# 2     Other                NaN     NaN       NaN           NaN         NaN
# 3     Steel         1901-01-01     NaN       NaN           NaN         NaN
# 4     Steel         1901-01-01     NaN       NaN           NaN         NaN
#
#    speed_mph  height_value height_unit  height_ft  Inversions_clean  \
# 0        6.0          50.0          ft        NaN                 0
# 1        NaN           NaN         NaN        NaN                 1
# 2        NaN           NaN         NaN        NaN                 0
# 3        NaN           NaN         NaN        NaN                 1
# 4        NaN           NaN         NaN        NaN                 1
#
#    Gforce_clean
# 0           2.9
# 1          12.0
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df.drop(['Manufacturer'], axis=1)
# Out:
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# 1                         NaN                   Sea Lion Park
# 2                         NaN  Cleveland, Ohio, United States
# 3                         NaN                           Other
# 4                         NaN                           Other
# ...                       ...                             ...
# 1082         53 mph (85 km/h)                           Other
# 1083        73 mph (117 km/h)      Busch Gardens Williamsburg
# 1084  59.3[1] mph (95.4 km/h)                           Other
# 1085         34 mph (55 km/h)                  Kings Dominion
# 1086         58 mph (93 km/h)        Six Flags Magic Mountain
#
#                   Status   Opening date                                  Type  \
# 0                Removed  June 16, 1884                                  Wood
# 1                Removed           1895                                  Wood
# 2                 Closed            NaN                                 Other
# 3                Removed           1901                                 Steel
# 4                Removed           1901                                 Steel
# ...                  ...            ...                                   ...
# 1082                 NaN            NaN                                 Steel
# 1083  Under construction           2022                      Steel – Launched
# 1084                 NaN  June 16, 2016                      Steel – Launched
# 1085  Under construction            NaN  Steel – 4th Dimension – Wing Coaster
# 1086  Under construction           2022                   Steel – Single-rail
#
#      Height restriction                     Model            Height  \
# 0                   NaN               Lift Packed      50 ft (15 m)
# 1                   NaN                       NaN               NaN
# 2                   NaN                       NaN               NaN
# 3                   NaN                       NaN               NaN
# 4                   NaN                       NaN               NaN
# ...                 ...                       ...               ...
# 1082     55 in (140 cm)                       NaN     111 ft (34 m)
# 1083                NaN             Blitz Coaster     178 ft (54 m)
# 1084   4[2] ft (122 cm)  Motorbike roller coaster  78.1 ft (23.8 m)
# 1085                NaN              4D Free Spin     112 ft (34 m)
# 1086                NaN           Raptor – Custom     131 ft (40 m)
#
#       Inversions        Lift/launch system Cost  \
# 0            NaN                   gravity  NaN
# 1            1.0                       NaN  NaN
# 2            NaN                       NaN  NaN
# 3            1.0                       NaN  NaN
# 4            1.0                       NaN  NaN
# ...          ...                       ...  ...
# 1082         3.0   Booster Wheel Lift Hill  NaN
# 1083         2.0                       LSM  NaN
# 1084         0.0                LIM Launch  NaN
# 1085         0.0  Vertical chain lift hill  NaN
# 1086         3.0           Chain lift hill  NaN
#
#                                                  Trains  \
# 0                                                   NaN
# 1     a single car. Riders are arranged 1 across in ...
# 2                                                   NaN
# 3     a single car. Riders are arranged 2 across in ...
# 4                                                   NaN
# ...                                                 ...
# 1082  3 trains with 5 cars. Riders are arranged 2 ac...
# 1083  2 trains with 5 cars. Riders are arranged 2 ac...
# 1084  7 trains with 7 cars. Riders are arranged 2 ac...
# 1085  Single car trains with riders arranged 4 acros...
# 1086                                                NaN
#
#                    Park section Duration               Capacity G-force  \
# 0     Coney Island Cyclone Site     1:00   1600 riders per hour     2.9
# 1                           NaN      NaN                    NaN      12
# 2                           NaN      NaN                    NaN     NaN
# 3                           NaN      NaN                    NaN     NaN
# 4                           NaN      NaN                    NaN     NaN
# ...                         ...      ...                    ...     ...
# 1082                        NaN      NaN  1,500 riders per hour     4.7
# 1083                        NaN      NaN                    NaN     NaN
# 1084                        NaN    ~2:00  1,680 riders per hour       4
# 1085          Jungle X-Pedition     0:55                    NaN     NaN
# 1086                DC Universe      NaN                    NaN     NaN
#
#                       Designer Max vertical angle           Drop  \
# 0       LaMarcus Adna Thompson                30°   43 ft (13 m)
# 1                 Lina Beecher                NaN            NaN
# 2                          NaN                NaN            NaN
# 3              Edward A. Green                NaN            NaN
# 4              Edward A. Green                NaN            NaN
# ...                        ...                ...            ...
# 1082            Werner Stengel                NaN            NaN
# 1083                       NaN                95°            NaN
# 1084  Walt Disney Imagineering                NaN            NaN
# 1085                       NaN                NaN            NaN
# 1086                       NaN                87°  127 ft (39 m)
#
#      Soft opening date Fast Lane available  \
# 0                  NaN                 NaN
# 1                  NaN                 NaN
# 2                  NaN                 NaN
# 3                  NaN                 NaN
# 4                  NaN                 NaN
# ...                ...                 ...
# 1082               NaN                 NaN
# 1083               NaN                 NaN
# 1084               NaN                 NaN
# 1085               NaN                 NaN
# 1086               NaN                 NaN
#
#                                     Replaced            Track layout  \
# 0                                        NaN  Gravity pulled coaster
# 1                                        NaN                     NaN
# 2                                        NaN                     NaN
# 3                         Switchback Railway                     NaN
# 4                                        NaN                     NaN
# ...                                      ...                     ...
# 1082                                     NaN                     NaN
# 1083                                     NaN                     NaN
# 1084                                     NaN                     NaN
# 1085                               The Crypt                     NaN
# 1086  Green Lantern: First Flight Tidal Wave                     NaN
#
#      Fastrack available Soft opening date.1 Closing date Opened  Replaced by  \
# 0                   NaN                 NaN          NaN    NaN          NaN
# 1                   NaN                 NaN         1902    NaN          NaN
# 2                   NaN                 NaN          NaN   1895          NaN
# 3                   NaN                 NaN         1910    NaN  Giant Racer
# 4                   NaN                 NaN         1912    NaN          NaN
# ...                 ...                 ...          ...    ...          ...
# 1082                NaN                 NaN          NaN    NaN          NaN
# 1083                NaN                 NaN          NaN    NaN          NaN
# 1084                NaN                 NaN          NaN    NaN          NaN
# 1085                NaN                 NaN          NaN    NaN          NaN
# 1086                NaN                 NaN          NaN    NaN          NaN
#
#                Website Flash Pass Available  Must transfer from wheelchair  \
# 0                  NaN                  NaN                            NaN
# 1                  NaN                  NaN                            NaN
# 2                  NaN                  NaN                            NaN
# 3                  NaN                  NaN                            NaN
# 4                  NaN                  NaN                            NaN
# ...                ...                  ...                            ...
# 1082               NaN                  NaN                            NaN
# 1083               NaN                  NaN                            NaN
# 1084               NaN                  NaN  Must transfer from wheelchair
# 1085  Official website                  NaN                            NaN
# 1086               NaN                  NaN                            NaN
#
#      Theme  Single rider line available Restraint Style Flash Pass available  \
# 0      NaN                          NaN             NaN                  NaN
# 1      NaN                          NaN             NaN                  NaN
# 2      NaN                          NaN             NaN                  NaN
# 3      NaN                          NaN             NaN                  NaN
# 4      NaN                          NaN             NaN                  NaN
# ...    ...                          ...             ...                  ...
# 1082   NaN                          NaN             NaN                  NaN
# 1083   NaN                          NaN             NaN                  NaN
# 1084  Tron  Single rider line available             NaN                  NaN
# 1085   NaN                          NaN             NaN                  NaN
# 1086   NaN                          NaN             NaN                  NaN
#
#      Acceleration Restraints                   Name  year_introduced  \
# 0             NaN        NaN                    NaN             1884
# 1             NaN        NaN                    NaN             1895
# 2             NaN        NaN                    NaN             1896
# 3             NaN        NaN                    NaN             1901
# 4             NaN        NaN                    NaN             1901
# ...           ...        ...                    ...              ...
# 1082          NaN        NaN                    NaN             2022
# 1083          NaN        NaN                    NaN             2022
# 1084          NaN        NaN  TRON Lightcycle / Run             2022
# 1085          NaN        NaN                    NaN             2022
# 1086          NaN        NaN                    NaN             2022
#
#       latitude  longitude Type_Main opening_date_clean     speed1     speed2  \
# 0      40.5740   -73.9780      Wood         1884-06-16     6 mph    9.7 km/h
# 1      40.5780   -73.9790      Wood         1895-01-01        NaN        NaN
# 2      41.5800   -81.5700     Other                NaN        NaN        NaN
# 3      40.5745   -73.9780     Steel         1901-01-01        NaN        NaN
# 4      39.3538   -74.4342     Steel         1901-01-01        NaN        NaN
# ...        ...        ...       ...                ...        ...        ...
# 1082       NaN        NaN     Steel                NaN    53 mph     85 km/h
# 1083   37.2339   -76.6426     Steel         2022-01-01    73 mph    117 km/h
# 1084       NaN        NaN     Steel         2016-06-16  59.3 mph   95.4 km/h
# 1085       NaN        NaN     Steel                NaN    34 mph     55 km/h
# 1086       NaN        NaN     Steel         2022-01-01    58 mph     93 km/h
#
#       speed1_value speed1_unit  speed_mph  height_value height_unit  \
# 0              6.0         mph        6.0          50.0          ft
# 1              NaN         NaN        NaN           NaN         NaN
# 2              NaN         NaN        NaN           NaN         NaN
# 3              NaN         NaN        NaN           NaN         NaN
# 4              NaN         NaN        NaN           NaN         NaN
# ...            ...         ...        ...           ...         ...
# 1082          53.0         mph       53.0         111.0          ft
# 1083          73.0         mph       73.0         178.0          ft
# 1084          59.3         mph       59.3          78.1          ft
# 1085          34.0         mph       34.0         112.0          ft
# 1086          58.0         mph       58.0         131.0          ft
#
#       height_ft  Inversions_clean  Gforce_clean
# 0           NaN                 0           2.9
# 1           NaN                 1          12.0
# 2           NaN                 0           NaN
# 3           NaN                 1           NaN
# 4           NaN                 1           NaN
# ...         ...               ...           ...
# 1082        NaN                 3           4.7
# 1083        NaN                 2           NaN
# 1084        NaN                 0           4.0
# 1085        NaN                 0           NaN
# 1086        NaN                 3           NaN
#
# [1087 rows x 55 columns]

# %%
df.head(5)
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# 0  LaMarcus Adna Thompson                NaN  Lift Packed  50 ft (15 m)
# 1            Lina Beecher                NaN          NaN           NaN
# 2                     NaN                NaN          NaN           NaN
# 3          Edwin Prescott                NaN          NaN           NaN
# 4          Edwin Prescott                NaN          NaN           NaN
#
#    Inversions Lift/launch system Cost  \
# 0         NaN            gravity  NaN
# 1         1.0                NaN  NaN
# 2         NaN                NaN  NaN
# 3         1.0                NaN  NaN
# 4         1.0                NaN  NaN
#
#                                               Trains  \
# 0                                                NaN
# 1  a single car. Riders are arranged 1 across in ...
# 2                                                NaN
# 3  a single car. Riders are arranged 2 across in ...
# 4                                                NaN
#
#                 Park section Duration              Capacity G-force  \
# 0  Coney Island Cyclone Site     1:00  1600 riders per hour     2.9
# 1                        NaN      NaN                   NaN      12
# 2                        NaN      NaN                   NaN     NaN
# 3                        NaN      NaN                   NaN     NaN
# 4                        NaN      NaN                   NaN     NaN
#
#                  Designer Max vertical angle          Drop Soft opening date  \
# 0  LaMarcus Adna Thompson                30°  43 ft (13 m)               NaN
# 1            Lina Beecher                NaN           NaN               NaN
# 2                     NaN                NaN           NaN               NaN
# 3         Edward A. Green                NaN           NaN               NaN
# 4         Edward A. Green                NaN           NaN               NaN
#
#   Fast Lane available            Replaced            Track layout  \
# 0                 NaN                 NaN  Gravity pulled coaster
# 1                 NaN                 NaN                     NaN
# 2                 NaN                 NaN                     NaN
# 3                 NaN  Switchback Railway                     NaN
# 4                 NaN                 NaN                     NaN
#
#   Fastrack available Soft opening date.1 Closing date Opened  Replaced by  \
# 0                NaN                 NaN          NaN    NaN          NaN
# 1                NaN                 NaN         1902    NaN          NaN
# 2                NaN                 NaN          NaN   1895          NaN
# 3                NaN                 NaN         1910    NaN  Giant Racer
# 4                NaN                 NaN         1912    NaN          NaN
#
#   Website Flash Pass Available Must transfer from wheelchair Theme  \
# 0     NaN                  NaN                           NaN   NaN
# 1     NaN                  NaN                           NaN   NaN
# 2     NaN                  NaN                           NaN   NaN
# 3     NaN                  NaN                           NaN   NaN
# 4     NaN                  NaN                           NaN   NaN
#
#   Single rider line available Restraint Style Flash Pass available  \
# 0                         NaN             NaN                  NaN
# 1                         NaN             NaN                  NaN
# 2                         NaN             NaN                  NaN
# 3                         NaN             NaN                  NaN
# 4                         NaN             NaN                  NaN
#
#   Acceleration Restraints Name  year_introduced  latitude  longitude  \
# 0          NaN        NaN  NaN             1884   40.5740   -73.9780
# 1          NaN        NaN  NaN             1895   40.5780   -73.9790
# 2          NaN        NaN  NaN             1896   41.5800   -81.5700
# 3          NaN        NaN  NaN             1901   40.5745   -73.9780
# 4          NaN        NaN  NaN             1901   39.3538   -74.4342
#
#   Type_Main opening_date_clean  speed1    speed2  speed1_value speed1_unit  \
# 0      Wood         1884-06-16  6 mph   9.7 km/h           6.0         mph
# 1      Wood         1895-01-01     NaN       NaN           NaN         NaN
# 2     Other                NaN     NaN       NaN           NaN         NaN
# 3     Steel         1901-01-01     NaN       NaN           NaN         NaN
# 4     Steel         1901-01-01     NaN       NaN           NaN         NaN
#
#    speed_mph  height_value height_unit  height_ft  Inversions_clean  \
# 0        6.0          50.0          ft        NaN                 0
# 1        NaN           NaN         NaN        NaN                 1
# 2        NaN           NaN         NaN        NaN                 0
# 3        NaN           NaN         NaN        NaN                 1
# 4        NaN           NaN         NaN        NaN                 1
#
#    Gforce_clean
# 0           2.9
# 1          12.0
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df.duplicated(subset = ['coaster_name','Location', 'Opening date'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082     True
# 1083    False
# 1084     True
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
df.loc[df.duplicated(subset = ['coaster_name','Location', 'Opening date'])]
# Out:
#                             coaster_name                Length  \
# 43                 Crystal Beach Cyclone      2,953 ft (900 m)
# 60                           Derby Racer                   NaN
# 61           Blue Streak (Conneaut Lake)      2,900 ft (880 m)
# 167        Big Thunder Mountain Railroad                   NaN
# 237    Thunder Run (Canada's Wonderland)      330 m (1,080 ft)
# ...                                  ...                   ...
# 1063                  Lil' Devil Coaster     262.5 ft (80.0 m)
# 1064  Little Dipper (Conneaut Lake Park)                   NaN
# 1080                          Iron Gwazi    4,075 ft (1,242 m)
# 1082             American Dreier Looping    3,444 ft (1,050 m)
# 1084           Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
#
#                         Speed                   Location              Status  \
# 43           60 mph (97 km/h)         Crystal Beach Park             Removed
# 60                        NaN               Revere Beach             Removed
# 61           50 mph (80 km/h)         Conneaut Lake Park              Closed
# 167          35 mph (56 km/h)                      Other                 NaN
# 237          64 km/h (40 mph)        Canada's Wonderland           Operating
# ...                       ...                        ...                 ...
# 1063                      NaN  Six Flags Great Adventure           Operating
# 1064                      NaN         Conneaut Lake Park           Operating
# 1080        76 mph (122 km/h)    Busch Gardens Tampa Bay  Under construction
# 1082         53 mph (85 km/h)                      Other                 NaN
# 1084  59.3[1] mph (95.4 km/h)                      Other                 NaN
#
#                                            Opening date  \
# 43                                                 1926
# 60                                                 1911
# 61                                         May 23, 1938
# 167                                                 NaN
# 237   May 23, 1981 as Blauer Enzian, 1986 as Thunder...
# ...                                                 ...
# 1063  1999 as Road Runner Railway; 2021 as Lil' Devi...
# 1064                                              1950s
# 1080                                                NaN
# 1082                                                NaN
# 1084                                      June 16, 2016
#
#                               Type  \
# 43                            Wood
# 60                   Wood – Racing
# 61                            Wood
# 167             Steel – Mine Train
# 237   Steel – Powered – Mine Train
# ...                            ...
# 1063                Steel – Kiddie
# 1064                         Steel
# 1080                Steel – Wooden
# 1082                         Steel
# 1084              Steel – Launched
#
#                                            Manufacturer  Height restriction  \
# 43                                   Traver Engineering                 NaN
# 60                                       Fred W. Pearce                 NaN
# 61                                                  NaN                 NaN
# 167   Arrow Development (California and Florida)Dyna...      40 in (102 cm)
# 237                                          Mack Rides  102 cm (3 ft 4 in)
# ...                                                 ...                 ...
# 1063                                           Zamperla                 NaN
# 1064                            Allan Herschell Company                 NaN
# 1080                        Rocky Mountain Construction   48[1] in (122 cm)
# 1082                                  Anton Schwarzkopf      55 in (140 cm)
# 1084                                             Vekoma    4[2] ft (122 cm)
#
#                              Model            Height  Inversions  \
# 43                             NaN      96 ft (29 m)         NaN
# 60                             NaN               NaN         0.0
# 61     Out and Back roller coaster      77 ft (23 m)         0.0
# 167                     Mine Train     104 ft (32 m)         0.0
# 237                            NaN      10 m (33 ft)         0.0
# ...                            ...               ...         ...
# 1063  Family Gravity Coaster 80STD     13 ft (4.0 m)         0.0
# 1064                 Little Dipper               NaN         NaN
# 1080                   I-Box Track     206 ft (63 m)         2.0
# 1082                           NaN     111 ft (34 m)         3.0
# 1084      Motorbike roller coaster  78.1 ft (23.8 m)         0.0
#
#            Lift/launch system          Cost  \
# 43                 Chain-lift  $176,000 CDN
# 60                        NaN      $140,000
# 61                        NaN           NaN
# 167           Chain lift hill           NaN
# 237                       NaN    $2.7M est.
# ...                       ...           ...
# 1063          Chain lift hill           NaN
# 1064          Chain lift hill           NaN
# 1080          Chain lift hill           NaN
# 1082  Booster Wheel Lift Hill           NaN
# 1084               LIM Launch           NaN
#
#                                                  Trains  \
# 43                                                  NaN
# 60                                                  NaN
# 61    Single train with 3 cars. Riders are arranged ...
# 167                                                 NaN
# 237   Single train with 10 cars. Riders are arranged...
# ...                                                 ...
# 1063  Single train with 6 cars. Riders are arranged ...
# 1064                                                NaN
# 1080  2 trains with 6 cars. Riders are arranged 2 ac...
# 1082  3 trains with 5 cars. Riders are arranged 2 ac...
# 1084  7 trains with 7 cars. Riders are arranged 2 ac...
#
#                 Park section Duration               Capacity G-force  \
# 43               Cyclone Bay     1:10     85 riders per hour    4 Gs
# 60                       NaN      NaN                    NaN     NaN
# 61                       NaN     2:20                    NaN     NaN
# 167                      NaN    ~3:00                    NaN     NaN
# 237   International Festival     1:24                    NaN     NaN
# ...                      ...      ...                    ...     ...
# 1063    Looney Tunes Seaport     0:40                    NaN     NaN
# 1064                     NaN      NaN                    NaN     NaN
# 1080                 Morocco     1:50                    NaN     NaN
# 1082                     NaN      NaN  1,500 riders per hour     4.7
# 1084                     NaN    ~2:00  1,680 riders per hour       4
#
#                       Designer Max vertical angle           Drop  \
# 43             Harry G. Traver                59°   90 ft (27 m)
# 60                         NaN                NaN            NaN
# 61                   Ed Vettel                NaN            NaN
# 167   Walt Disney Imagineering                NaN            NaN
# 237                        NaN                NaN            NaN
# ...                        ...                ...            ...
# 1063                       NaN                NaN            NaN
# 1064                       NaN                NaN            NaN
# 1080              Alan Schilke                91°  206 ft (63 m)
# 1082            Werner Stengel                NaN            NaN
# 1084  Walt Disney Imagineering                NaN            NaN
#
#      Soft opening date Fast Lane available  \
# 43                 NaN                 NaN
# 60                 NaN                 NaN
# 61                 NaN                 NaN
# 167                NaN                 NaN
# 237                NaN                 NaN
# ...                ...                 ...
# 1063               NaN                 NaN
# 1064               NaN                 NaN
# 1080               NaN                 NaN
# 1082               NaN                 NaN
# 1084               NaN                 NaN
#
#                                     Replaced           Track layout  \
# 43                                       NaN                Twister
# 60                                       NaN           Figure Eight
# 61                                       NaN                    NaN
# 167   Mine Train Through Nature's Wonderland                 Custom
# 237                                      NaN                    NaN
# ...                                      ...                    ...
# 1063                                     NaN  Single Helix (center)
# 1064                                     NaN                   Oval
# 1080                                   Gwazi                Twister
# 1082                                     NaN                    NaN
# 1084                                     NaN                    NaN
#
#      Fastrack available Soft opening date.1       Closing date Opened  \
# 43                  NaN                 NaN  September 2, 1946    NaN
# 60                  NaN                 NaN               1936    NaN
# 61                  NaN                 NaN                NaN    NaN
# 167                 NaN                 NaN                NaN    NaN
# 237                 NaN                 NaN                NaN    NaN
# ...                 ...                 ...                ...    ...
# 1063                NaN                 NaN                NaN    NaN
# 1064                NaN                 NaN                NaN    NaN
# 1080                NaN                 NaN                NaN    NaN
# 1082                NaN                 NaN                NaN    NaN
# 1084                NaN                 NaN                NaN    NaN
#
#      Replaced by Website Flash Pass Available  Must transfer from wheelchair  \
# 43           NaN     NaN                  NaN                            NaN
# 60           NaN     NaN                  NaN                            NaN
# 61           NaN     NaN                  NaN                            NaN
# 167          NaN     NaN                  NaN  Must transfer from wheelchair
# 237          NaN     NaN                  NaN                            NaN
# ...          ...     ...                  ...                            ...
# 1063         NaN     NaN                  NaN                            NaN
# 1064         NaN     NaN                  NaN                            NaN
# 1080         NaN     NaN                  NaN                            NaN
# 1082         NaN     NaN                  NaN                            NaN
# 1084         NaN     NaN                  NaN  Must transfer from wheelchair
#
#      Theme  Single rider line available Restraint Style Flash Pass available  \
# 43     NaN                          NaN             NaN                  NaN
# 60     NaN                          NaN             NaN                  NaN
# 61     NaN                          NaN             NaN                  NaN
# 167    NaN  Single rider line available             NaN                  NaN
# 237    NaN                          NaN             NaN                  NaN
# ...    ...                          ...             ...                  ...
# 1063   NaN                          NaN             NaN                  NaN
# 1064   NaN                          NaN             NaN                  NaN
# 1080   NaN                          NaN             NaN                  NaN
# 1082   NaN                          NaN             NaN                  NaN
# 1084  Tron  Single rider line available             NaN                  NaN
#
#      Acceleration      Restraints                   Name  year_introduced  \
# 43            NaN             NaN                    NaN             1927
# 60            NaN             NaN                    NaN             1937
# 61            NaN             NaN                    NaN             1938
# 167           NaN  Single Lap Bar                    NaN             1980
# 237           NaN             NaN                    NaN             1986
# ...           ...             ...                    ...              ...
# 1063          NaN             NaN                    NaN             2021
# 1064          NaN             NaN                    NaN             2021
# 1080          NaN             NaN                    NaN             2022
# 1082          NaN             NaN                    NaN             2022
# 1084          NaN             NaN  TRON Lightcycle / Run             2022
#
#       latitude  longitude Type_Main opening_date_clean     speed1     speed2  \
# 43     42.8617   -79.0598      Wood         1926-01-01    60 mph     97 km/h
# 60     42.4200   -70.9860      Wood         1911-01-01        NaN        NaN
# 61     41.6349   -80.3180      Wood         1938-05-23    50 mph     80 km/h
# 167        NaN        NaN     Steel                NaN    35 mph     56 km/h
# 237    43.8427   -79.5423     Steel         1981-05-23   64 km/h      40 mph
# ...        ...        ...       ...                ...        ...        ...
# 1063   40.1343   -74.4434     Steel         1999-01-01        NaN        NaN
# 1064   41.6343   -80.3165     Steel         1950-01-01        NaN        NaN
# 1080   28.0339   -82.4231     Steel                NaN    76 mph    122 km/h
# 1082       NaN        NaN     Steel                NaN    53 mph     85 km/h
# 1084       NaN        NaN     Steel         2016-06-16  59.3 mph   95.4 km/h
#
#       speed1_value speed1_unit  speed_mph  height_value height_unit  \
# 43            60.0         mph       60.0          96.0          ft
# 60             NaN         NaN        NaN           NaN         NaN
# 61            50.0         mph       50.0          77.0          ft
# 167           35.0         mph       35.0         104.0          ft
# 237           64.0        km/h       39.8          10.0           m
# ...            ...         ...        ...           ...         ...
# 1063           NaN         NaN        NaN          13.0          ft
# 1064           NaN         NaN        NaN           NaN         NaN
# 1080          76.0         mph       76.0         206.0          ft
# 1082          53.0         mph       53.0         111.0          ft
# 1084          59.3         mph       59.3          78.1          ft
#
#       height_ft  Inversions_clean  Gforce_clean
# 43          NaN                 0           4.0
# 60          NaN                 0           NaN
# 61          NaN                 0           NaN
# 167         NaN                 0           NaN
# 237        32.8                 0           NaN
# ...         ...               ...           ...
# 1063        NaN                 0           NaN
# 1064        NaN                 0           NaN
# 1080        NaN                 2           NaN
# 1082        NaN                 3           4.7
# 1084        NaN                 0           4.0
#
# [97 rows x 56 columns]
